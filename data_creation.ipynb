# %%
import pandas as pd
import glob
import os
from datetime import timedelta
import copy
path = "./preprocessed/"
output_path = "./data/"

# %% [markdown]
# #  Fast check to see dates and determine test/train interval according to that

# %%
import warnings
warnings.filterwarnings('ignore')

for ix, intrctn in enumerate(["df_visit.csv", "df_basket.csv", "df_fav.csv", "df_trx.csv"]):

    df_event = pd.read_pickle(f"{path}{intrctn}.pkl")
    print(intrctn)
    display(df_event["date"].describe())
# Out:
# df_visit.csv
# count                 8567033
# unique                     31
# top       2020-10-06 00:00:00
# freq                   462160
# first     2020-10-01 00:00:00
# last      2020-10-31 00:00:00
# Name: date, dtype: object
# df_basket.csv
# count                  283442
# unique                     31
# top       2020-10-08 00:00:00
# freq                    24794
# first     2020-10-01 00:00:00
# last      2020-10-31 00:00:00
# Name: date, dtype: object
# df_fav.csv
# count                  398720
# unique                     31
# top       2020-10-06 00:00:00
# freq                    23252
# first     2020-10-01 00:00:00
# last      2020-10-31 00:00:00
# Name: date, dtype: object
# df_trx.csv
# count                  228011
# unique                     32
# top       2020-10-08 00:00:00
# freq                    16963
# first     2020-10-01 00:00:00
# last      2020-11-01 00:00:00
# Name: date, dtype: object

# %% [markdown]
# ## Lets talk about how we create our train/test instances and features  with an example
#
# - If 31 october, 30 october, 29 october will be test days (test interval), that means we want to make prediction for instances in 28 october
#
#     -- So, we should filter train/test data according to user-currentbugroupname pairs at 28 october
# - if user-currentbugroupname pairs at 28 october in train/test data have a purchase in these days, then this pairs will positive samples
# - other days will be used for feature generation since other days are in train period
#
# - With the algorithm above, we assign labels and create features for user-currentbugroupname pairs at each day in the collected data
# - We will train our binary classfication ml models for each days' train/test instances and save their classfication metrics
# - mean and std of classification results for each day will be the final result

# %%
import datetime, calendar

year = 2020
month = 10
num_days = calendar.monthrange(year, month)[1]
days = [datetime.date(year, 10, day) for day in range(1, 32)]
df_purchased = pd.read_pickle(f"{path}df_trx.csv.pkl")

# %%
import warnings
warnings.filterwarnings('ignore')

for the_day in days:

    the_day_str = the_day.strftime('%Y-%m-%d')
    test_start_day = (datetime.datetime.strptime(the_day_str, '%Y-%m-%d')  + timedelta(days=1)).strftime('%Y-%m-%d')
    test_end_day = (datetime.datetime.strptime(the_day_str, '%Y-%m-%d')  + timedelta(days=3)).strftime('%Y-%m-%d')
    


    #gather the events that happen in the_day and assign target that show which of user-bugroup pair purchased in nex 3 days

    print(the_day_str)
    print(test_start_day)
    print(test_end_day)
    
    pd_list = []

    for intrctn in ["df_visit.csv", "df_basket.csv", "df_fav.csv", "df_trx.csv"]:
        
        #filter event data according to date
        intrctn_df = pd.read_pickle(f'{path}{intrctn}.pkl')
        intrctn_df_the_day = intrctn_df[intrctn_df["date"] == the_day_str]

        if intrctn_df_the_day.shape[0] == 0:
            continue
        
        #filter purchased data according to date
        pos = df_purchased[(df_purchased["date"] >= test_start_day)&(df_purchased["date"] <= test_end_day)]
        pos["label"] = 1
        
        #assign label to events that shows whether user-bugroup pair purchased in nex 3 days
        unpickled_df = pd.merge(intrctn_df_the_day[["userid", "currentbugroupname"]], pos[["userid", "currentbugroupname", "label"]], how='left', on=["userid", "currentbugroupname"])
        unpickled_df=unpickled_df.fillna(0)
        pd_list.append(unpickled_df)

    # concat each event and check pos/neg samples

    if len(pd_list) > 0:
        events = pd.concat(pd_list)
        events.drop_duplicates(inplace=True)
        print("pos/neg dist of the day for all events: instance count", events.shape, "pos", events[events["label"]==1].shape, "neg",events[events["label"]==0].shape)


        #filter events according to event in the_day
        for split in ["df_target_train.csv", "df_test.csv"]:

            split_df = pd.read_pickle(f'{path}{split}.pkl')
            print("size before the inner join",split, split_df.shape)
            split_df = pd.merge(split_df[["userid", "currentbugroupname"]], events[["userid", "currentbugroupname", "label"]], how='inner', on=["userid", "currentbugroupname"])
            print("size after the inner join",split, split_df.shape)
            print(f"pos/neg dist of the day for {split}: instance count", split_df.shape, "pos", split_df[split_df["label"]==1].shape, "neg", split_df[split_df["label"]==0].shape)
            split_df.to_pickle(f'{output_path}{split}_{the_day}.pkl')

    else:
        break

    print("********************************************************************************************")
# Out:
# 2020-10-01
# 2020-10-02
# 2020-10-04
# pos/neg dist of the day for all events: instance count (52829, 3) pos (3664, 3) neg (49165, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4397, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4397, 3) pos (549, 3) neg (3848, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (23344, 3)
# pos/neg dist of the day for df_test.csv: instance count (23344, 3) pos (1843, 3) neg (21501, 3)
# ********************************************************************************************
# 2020-10-02
# 2020-10-03
# 2020-10-05
# pos/neg dist of the day for all events: instance count (50337, 3) pos (4050, 3) neg (46287, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4302, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4302, 3) pos (624, 3) neg (3678, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (22146, 3)
# pos/neg dist of the day for df_test.csv: instance count (22146, 3) pos (2015, 3) neg (20131, 3)
# ********************************************************************************************
# 2020-10-03
# 2020-10-04
# 2020-10-06
# pos/neg dist of the day for all events: instance count (48400, 3) pos (5887, 3) neg (42513, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4325, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4325, 3) pos (836, 3) neg (3489, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (22385, 3)
# pos/neg dist of the day for df_test.csv: instance count (22385, 3) pos (2907, 3) neg (19478, 3)
# ********************************************************************************************
# 2020-10-04
# 2020-10-05
# 2020-10-07
# pos/neg dist of the day for all events: instance count (50908, 3) pos (7609, 3) neg (43299, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4543, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4543, 3) pos (1066, 3) neg (3477, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (23548, 3)
# pos/neg dist of the day for df_test.csv: instance count (23548, 3) pos (3731, 3) neg (19817, 3)
# ********************************************************************************************
# 2020-10-05
# 2020-10-06
# 2020-10-08
# pos/neg dist of the day for all events: instance count (73076, 3) pos (11681, 3) neg (61395, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5854, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5854, 3) pos (1516, 3) neg (4338, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (31993, 3)
# pos/neg dist of the day for df_test.csv: instance count (31993, 3) pos (5816, 3) neg (26177, 3)
# ********************************************************************************************
# 2020-10-06
# 2020-10-07
# 2020-10-09
# pos/neg dist of the day for all events: instance count (103540, 3) pos (11996, 3) neg (91544, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (7356, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (7356, 3) pos (1526, 3) neg (5830, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (44073, 3)
# pos/neg dist of the day for df_test.csv: instance count (44073, 3) pos (5969, 3) neg (38104, 3)
# ********************************************************************************************
# 2020-10-07
# 2020-10-08
# 2020-10-10
# pos/neg dist of the day for all events: instance count (100258, 3) pos (9116, 3) neg (91142, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (6854, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (6854, 3) pos (1166, 3) neg (5688, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (41108, 3)
# pos/neg dist of the day for df_test.csv: instance count (41108, 3) pos (4582, 3) neg (36526, 3)
# ********************************************************************************************
# 2020-10-08
# 2020-10-09
# 2020-10-11
# pos/neg dist of the day for all events: instance count (98661, 3) pos (5814, 3) neg (92847, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (6742, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (6742, 3) pos (826, 3) neg (5916, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (39643, 3)
# pos/neg dist of the day for df_test.csv: instance count (39643, 3) pos (2927, 3) neg (36716, 3)
# ********************************************************************************************
# 2020-10-09
# 2020-10-10
# 2020-10-12
# pos/neg dist of the day for all events: instance count (71105, 3) pos (4199, 3) neg (66906, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5312, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5312, 3) pos (629, 3) neg (4683, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (29076, 3)
# pos/neg dist of the day for df_test.csv: instance count (29076, 3) pos (2148, 3) neg (26928, 3)
# ********************************************************************************************
# 2020-10-10
# 2020-10-11
# 2020-10-13
# pos/neg dist of the day for all events: instance count (56837, 3) pos (4174, 3) neg (52663, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4896, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4896, 3) pos (646, 3) neg (4250, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26042, 3)
# pos/neg dist of the day for df_test.csv: instance count (26042, 3) pos (2126, 3) neg (23916, 3)
# ********************************************************************************************
# 2020-10-11
# 2020-10-12
# 2020-10-14
# pos/neg dist of the day for all events: instance count (54210, 3) pos (4153, 3) neg (50057, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4808, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4808, 3) pos (627, 3) neg (4181, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (25293, 3)
# pos/neg dist of the day for df_test.csv: instance count (25293, 3) pos (2145, 3) neg (23148, 3)
# ********************************************************************************************
# 2020-10-12
# 2020-10-13
# 2020-10-15
# pos/neg dist of the day for all events: instance count (56846, 3) pos (4541, 3) neg (52305, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4935, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4935, 3) pos (702, 3) neg (4233, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (25805, 3)
# pos/neg dist of the day for df_test.csv: instance count (25805, 3) pos (2342, 3) neg (23463, 3)
# ********************************************************************************************
# 2020-10-13
# 2020-10-14
# 2020-10-16
# pos/neg dist of the day for all events: instance count (56033, 3) pos (4603, 3) neg (51430, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4902, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4902, 3) pos (688, 3) neg (4214, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (25499, 3)
# pos/neg dist of the day for df_test.csv: instance count (25499, 3) pos (2353, 3) neg (23146, 3)
# ********************************************************************************************
# 2020-10-14
# 2020-10-15
# 2020-10-17
# pos/neg dist of the day for all events: instance count (55494, 3) pos (4678, 3) neg (50816, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4831, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4831, 3) pos (723, 3) neg (4108, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (24897, 3)
# pos/neg dist of the day for df_test.csv: instance count (24897, 3) pos (2364, 3) neg (22533, 3)
# ********************************************************************************************
# 2020-10-15
# 2020-10-16
# 2020-10-18
# pos/neg dist of the day for all events: instance count (55332, 3) pos (4461, 3) neg (50871, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4846, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4846, 3) pos (679, 3) neg (4167, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (24230, 3)
# pos/neg dist of the day for df_test.csv: instance count (24230, 3) pos (2214, 3) neg (22016, 3)
# ********************************************************************************************
# 2020-10-16
# 2020-10-17
# 2020-10-19
# pos/neg dist of the day for all events: instance count (55857, 3) pos (4605, 3) neg (51252, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (4867, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (4867, 3) pos (712, 3) neg (4155, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (24569, 3)
# pos/neg dist of the day for df_test.csv: instance count (24569, 3) pos (2314, 3) neg (22255, 3)
# ********************************************************************************************
# 2020-10-17
# 2020-10-18
# 2020-10-20
# pos/neg dist of the day for all events: instance count (54491, 3) pos (5048, 3) neg (49443, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5013, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5013, 3) pos (777, 3) neg (4236, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (24958, 3)
# pos/neg dist of the day for df_test.csv: instance count (24958, 3) pos (2488, 3) neg (22470, 3)
# ********************************************************************************************
# 2020-10-18
# 2020-10-19
# 2020-10-21
# pos/neg dist of the day for all events: instance count (57861, 3) pos (5679, 3) neg (52182, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5288, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5288, 3) pos (847, 3) neg (4441, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26748, 3)
# pos/neg dist of the day for df_test.csv: instance count (26748, 3) pos (2875, 3) neg (23873, 3)
# ********************************************************************************************
# 2020-10-19
# 2020-10-20
# 2020-10-22
# pos/neg dist of the day for all events: instance count (59714, 3) pos (5899, 3) neg (53815, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5298, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5298, 3) pos (888, 3) neg (4410, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26586, 3)
# pos/neg dist of the day for df_test.csv: instance count (26586, 3) pos (3008, 3) neg (23578, 3)
# ********************************************************************************************
# 2020-10-20
# 2020-10-21
# 2020-10-23
# pos/neg dist of the day for all events: instance count (64061, 3) pos (6039, 3) neg (58022, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5637, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5637, 3) pos (913, 3) neg (4724, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (28583, 3)
# pos/neg dist of the day for df_test.csv: instance count (28583, 3) pos (3076, 3) neg (25507, 3)
# ********************************************************************************************
# 2020-10-21
# 2020-10-22
# 2020-10-24
# pos/neg dist of the day for all events: instance count (66961, 3) pos (5463, 3) neg (61498, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5795, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5795, 3) pos (801, 3) neg (4994, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (29570, 3)
# pos/neg dist of the day for df_test.csv: instance count (29570, 3) pos (2812, 3) neg (26758, 3)
# ********************************************************************************************
# 2020-10-22
# 2020-10-23
# 2020-10-25
# pos/neg dist of the day for all events: instance count (63192, 3) pos (4721, 3) neg (58471, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5529, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5529, 3) pos (748, 3) neg (4781, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (27903, 3)
# pos/neg dist of the day for df_test.csv: instance count (27903, 3) pos (2352, 3) neg (25551, 3)
# ********************************************************************************************
# 2020-10-23
# 2020-10-24
# 2020-10-26
# pos/neg dist of the day for all events: instance count (58892, 3) pos (4466, 3) neg (54426, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5378, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5378, 3) pos (709, 3) neg (4669, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26023, 3)
# pos/neg dist of the day for df_test.csv: instance count (26023, 3) pos (2227, 3) neg (23796, 3)
# ********************************************************************************************
# 2020-10-24
# 2020-10-25
# 2020-10-27
# pos/neg dist of the day for all events: instance count (57069, 3) pos (4559, 3) neg (52510, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5557, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5557, 3) pos (738, 3) neg (4819, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26460, 3)
# pos/neg dist of the day for df_test.csv: instance count (26460, 3) pos (2273, 3) neg (24187, 3)
# ********************************************************************************************
# 2020-10-25
# 2020-10-26
# 2020-10-28
# pos/neg dist of the day for all events: instance count (55700, 3) pos (4455, 3) neg (51245, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5575, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5575, 3) pos (802, 3) neg (4773, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26250, 3)
# pos/neg dist of the day for df_test.csv: instance count (26250, 3) pos (2224, 3) neg (24026, 3)
# ********************************************************************************************
# 2020-10-26
# 2020-10-27
# 2020-10-29
# pos/neg dist of the day for all events: instance count (61541, 3) pos (4607, 3) neg (56934, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5859, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5859, 3) pos (839, 3) neg (5020, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (27518, 3)
# pos/neg dist of the day for df_test.csv: instance count (27518, 3) pos (2297, 3) neg (25221, 3)
# ********************************************************************************************
# 2020-10-27
# 2020-10-28
# 2020-10-30
# pos/neg dist of the day for all events: instance count (59519, 3) pos (4368, 3) neg (55151, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (5918, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (5918, 3) pos (812, 3) neg (5106, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26675, 3)
# pos/neg dist of the day for df_test.csv: instance count (26675, 3) pos (2157, 3) neg (24518, 3)
# ********************************************************************************************
# 2020-10-28
# 2020-10-29
# 2020-10-31
# pos/neg dist of the day for all events: instance count (58408, 3) pos (4291, 3) neg (54117, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (6173, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (6173, 3) pos (746, 3) neg (5427, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (26438, 3)
# pos/neg dist of the day for df_test.csv: instance count (26438, 3) pos (2165, 3) neg (24273, 3)
# ********************************************************************************************
# 2020-10-29
# 2020-10-30
# 2020-11-01
# pos/neg dist of the day for all events: instance count (59579, 3) pos (3300, 3) neg (56279, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (6593, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (6593, 3) pos (557, 3) neg (6036, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (27831, 3)
# pos/neg dist of the day for df_test.csv: instance count (27831, 3) pos (1713, 3) neg (26118, 3)
# ********************************************************************************************
# 2020-10-30
# 2020-10-31
# 2020-11-02
# pos/neg dist of the day for all events: instance count (54878, 3) pos (1864, 3) neg (53014, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (6413, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (6413, 3) pos (360, 3) neg (6053, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (25045, 3)
# pos/neg dist of the day for df_test.csv: instance count (25045, 3) pos (920, 3) neg (24125, 3)
# ********************************************************************************************
# 2020-10-31
# 2020-11-01
# 2020-11-03
# pos/neg dist of the day for all events: instance count (53525, 3) pos (405, 3) neg (53120, 3)
# size before the inner join df_target_train.csv (22864, 2)
# size after the inner join df_target_train.csv (7285, 3)
# pos/neg dist of the day for df_target_train.csv: instance count (7285, 3) pos (88, 3) neg (7197, 3)
# size before the inner join df_test.csv (230592, 4)
# size after the inner join df_test.csv (25055, 3)
# pos/neg dist of the day for df_test.csv: instance count (25055, 3) pos (202, 3) neg (24853, 3)
# ********************************************************************************************
